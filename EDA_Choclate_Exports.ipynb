# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the dataset
df=pd.read_excel('/content/ChoclateSales.xlsx')

# %%
df
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1          Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2         Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3         Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17    4410
# 1090    Jehu Rudeforth        USA           White Choc 2022-06-07    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26     574
# 1092    Dotty Strutley      India              Eclairs 2022-07-28    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites 2022-05-23    5075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %%
#Top rows are displayed
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
#Bottom rows are displayed
df.tail()
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims 2022-05-17    4410
# 1090    Jehu Rudeforth        USA           White Choc 2022-06-07    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup 2022-07-26     574
# 1092    Dotty Strutley      India              Eclairs 2022-07-28    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites 2022-05-23    5075
#
#       Boxes Shipped
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344

# %%
#No.of rows and columns in dataset is displayed
df.shape
# Out:
# (1094, 6)

# %%
#Summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   datetime64[ns]
#  4   Amount         1094 non-null   int64
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 51.4+ KB

# %%
#description of the dataset is known
df.describe()
# Out:
#                                 Date        Amount  Boxes Shipped
# count                           1094   1094.000000    1094.000000
# mean   2022-05-03 09:04:56.160877568   5652.308044     161.797989
# min              2022-01-03 00:00:00      7.000000       1.000000
# 25%              2022-03-02 00:00:00   2390.500000      70.000000
# 50%              2022-05-11 00:00:00   4868.500000     135.000000
# 75%              2022-07-04 00:00:00   8027.250000     228.750000
# max              2022-08-31 00:00:00  22050.000000     709.000000
# std                              NaN   4102.442014     121.544145

# %%
#Descriptive Statistics

# %%
df['Boxes Shipped'].min()
# Out:
# 1

# %%
df['Boxes Shipped'].max()
# Out:
# 709

# %%
df['Boxes Shipped'].mean()
# Out:
# 161.7979890310786

# %%
df['Boxes Shipped'].std()
# Out:
# 121.54414540536331

# %%
df.isnull().sum()
# Out:
# Sales Person     0
# Country          0
# Product          0
# Date             0
# Amount           0
# Boxes Shipped    0
# dtype: int64

# %%
df.nunique()
# Out:
# Sales Person      25
# Country            6
# Product           22
# Date             168
# Amount           827
# Boxes Shipped    385
# dtype: int64

# %%
#Sorting the data based on no.of box shipped and the maximum boxes shipped here are 709
df.sort_values(by='Boxes Shipped', ascending=False).head(6)
# Out:
#           Sales Person    Country               Product       Date  Amount  \
# 1028       Van Tuxwell     Canada         Drinking Coco 2022-06-15    4900
# 730   Karlen McCaffrey  Australia        50% Dark Bites 2022-01-17    6678
# 852     Marney O'Breen     Canada  Caramel Stuffed Bars 2022-02-23    1372
# 769   Karlen McCaffrey     Canada        70% Dark Bites 2022-06-24    7714
# 1070        Oby Sorrel     Canada               Eclairs 2022-05-19    6111
# 39    Karlen McCaffrey      India    Manuka Honey Choco 2022-07-04    2443
#
#       Boxes Shipped
# 1028            709
# 730             708
# 852             614
# 769             597
# 1070            591
# 39              581

# %%
df.groupby('Country') #Grouping the data based on country

# %%
df.groupby('Country')['Boxes Shipped'].max() # We group the different countries and then find the max boxes shipped.
# Out:
# Country
# Australia      708
# Canada         709
# India          581
# New Zealand    518
# UK             554
# USA            508
# Name: Boxes Shipped, dtype: int64

# %%
#What is the biggest brand every country consuming
df.groupby('Country')['Product'].max()
# Out:
# Country
# Australia      White Choc
# Canada         White Choc
# India          White Choc
# New Zealand    White Choc
# UK             White Choc
# USA            White Choc
# Name: Product, dtype: object

# %%
# Average boxes shipped by the sales persons
df.groupby('Sales Person')['Boxes Shipped'].mean()
# Out:
# Sales Person
# Andria Kimpton         165.333333
# Barr Faughny           148.046512
# Beverie Moffet         184.280000
# Brien Boise            152.867925
# Camilla Castle         167.937500
# Ches Bonnell           156.708333
# Curtice Advani         153.782609
# Dennison Crosswaite    178.918367
# Dotty Strutley         190.361111
# Gigi Bohling           134.106383
# Gunar Cockshoot        155.279070
# Husein Augar           153.921053
# Jan Morforth           196.435897
# Jehu Rudeforth         168.511628
# Kaine Padly            161.177778
# Karlen McCaffrey       205.489362
# Kelci Walkden          161.148148
# Madelene Upcott        161.755556
# Mallorie Waber         145.853659
# Marney O'Breen         178.733333
# Oby Sorrel             175.673469
# Rafaelita Blaksland    126.382353
# Roddy Speechley        160.441860
# Van Tuxwell            133.313725
# Wilone O'Kielt         118.617647
# Name: Boxes Shipped, dtype: float64

# %%
# which product sold more
df['Product'].max()
# Out:
# 'White Choc'

# %%
# Least sold product
df['Product'].min()
# Out:
# '50% Dark Bites'

# %%
#Boxes shipped per product
y = df.groupby('Product')['Boxes Shipped'].sum()
y
# Out:
# Product
# 50% Dark Bites          9792
# 70% Dark Bites          8015
# 85% Dark Bars           7793
# 99% Dark & Pure         8127
# After Nines             8257
# Almond Choco            6736
# Baker's Choco Chips     6998
# Caramel Stuffed Bars    8717
# Choco Coated Almonds    6464
# Drinking Coco           8660
# Eclairs                 8757
# Fruit & Nut Bars        7738
# Manuka Honey Choco      7781
# Milk Bars               8330
# Mint Chip Choco         8207
# Orange Choco            7732
# Organic Choco Syrup     7749
# Peanut Butter Cubes     8304
# Raspberry Choco         7115
# Smooth Sliky Salty      8810
# Spicy Special Slims     8685
# White Choc              8240
# Name: Boxes Shipped, dtype: int64

# %%
df.groupby('Country')['Boxes Shipped'].sum()
# Out:
# Country
# Australia      32647
# Canada         31221
# India          29470
# New Zealand    26580
# UK             30265
# USA            26824
# Name: Boxes Shipped, dtype: int64

# %%
#Cross validating if above data is correct
df['Boxes Shipped'].sum()
# Out:
# 177007

# %%
# In 2022 july whcih product sold most
july_2022_sales = df[(df['Date'].dt.year == 2022) & (df['Date'].dt.month == 7)]

# %%
#grouping the products with july 2022 july sales
df1=july_2022_sales.groupby('Product')['Boxes Shipped'].sum()

# %%
df1
# Out:
# Product
# 50% Dark Bites          1488
# 70% Dark Bites           195
# 85% Dark Bars            587
# 99% Dark & Pure          691
# After Nines             1372
# Almond Choco             734
# Baker's Choco Chips       24
# Caramel Stuffed Bars    1259
# Choco Coated Almonds     576
# Drinking Coco           1948
# Eclairs                 1060
# Fruit & Nut Bars        1367
# Manuka Honey Choco      2071
# Milk Bars               1296
# Mint Chip Choco         1246
# Orange Choco             428
# Organic Choco Syrup     2058
# Peanut Butter Cubes      947
# Raspberry Choco          163
# Smooth Sliky Salty       888
# Spicy Special Slims      672
# White Choc              1806
# Name: Boxes Shipped, dtype: int64

# %%
df1.idxmax()
# Out:
# 'Manuka Honey Choco'

# %%
df1.idxmin()
# Out:
# "Baker's Choco Chips"

# %%
#Finding the data having product name Choco in it
df[df['Product'].str.contains('Choco')]
# Out:
#              Sales Person      Country              Product       Date  \
# 0          Jehu Rudeforth           UK      Mint Chip Choco 2022-01-04
# 11           Barr Faughny          USA         Orange Choco 2022-03-10
# 15         Beverie Moffet    Australia  Organic Choco Syrup 2022-01-26
# 16            Van Tuxwell       Canada  Organic Choco Syrup 2022-02-14
# 29    Dennison Crosswaite  New Zealand   Manuka Honey Choco 2022-06-15
# ...                   ...          ...                  ...        ...
# 1079         Jan Morforth           UK  Baker's Choco Chips 2022-03-11
# 1082          Brien Boise          USA      Raspberry Choco 2022-01-12
# 1086  Dennison Crosswaite       Canada  Organic Choco Syrup 2022-01-28
# 1087       Beverie Moffet        India         Almond Choco 2022-05-24
# 1091         Ches Bonnell       Canada  Organic Choco Syrup 2022-07-26
#
#       Amount  Boxes Shipped
# 0       5320            180
# 11      3703             11
# ...

# %%
df['Product']
# Out:
# 0           Mint Chip Choco
# 1             85% Dark Bars
# 2       Peanut Butter Cubes
# 3       Peanut Butter Cubes
# 4       Peanut Butter Cubes
#                ...
# 1089    Spicy Special Slims
# 1090             White Choc
# 1091    Organic Choco Syrup
# 1092                Eclairs
# 1093         70% Dark Bites
# Name: Product, Length: 1094, dtype: object

# %%
df.Country.value_counts(normalize=True).plot.bar()
plt.show()

# %%
result = pd.pivot_table(data=df, index='Product', columns='Country',values='Boxes Shipped')
print(result)
#create heat map of Gender vs Temp vs SepsisLabel
sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()
# Out:
# Country                Australia      Canada       India  New Zealand  \
# Product
# 50% Dark Bites        198.875000  114.333333  154.625000   134.142857
# 70% Dark Bites        233.666667  197.250000  215.857143   155.500000
# 85% Dark Bars         150.000000  158.333333  176.000000   145.833333
# 99% Dark & Pure       122.727273  237.833333  181.875000   141.400000
# After Nines           130.285714  192.857143  187.400000   109.666667
# Almond Choco          197.636364   69.500000  144.000000   125.000000
# Baker's Choco Chips   139.666667  197.000000  253.000000   101.500000
# Caramel Stuffed Bars   84.857143  336.666667  181.666667   209.333333
# Choco Coated Almonds  119.666667  245.200000  189.714286   151.666667
# Drinking Coco         149.750000  220.000000  137.625000   202.166667
# Eclairs               133.100000  233.444444  132.333333    98.888889
# Fruit & Nut Bars      111.111111  156.900000  158.833333   129.125000
# ...
